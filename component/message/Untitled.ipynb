# %%
from pathlib import Path 

from sepal_ui.translator import Translator

# %%
# to test the translator for a specific language
locale = 'en'

# %%
ms = Translator(Path.cwd(), locale)

# %%
print(ms.missing_keys())
